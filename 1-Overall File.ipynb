# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 0
#
# Familirization of Python

# %% [markdown]
# No program just brief explanation about python

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 1
#
# Union and Intersection

# %%
a = []
b = []
c = []

m = int(input('Enter the range of first list:'))
n = int(input('Enter the range of second list:'))

print('Start entering the values into first list\n')

for i in range(m):
    d = int(input())
    a.append(d)

print('Start entering the values into second list\n')

for j in range(n):
    e = int(input())
    b.append(e)

a = list(dict.fromkeys(a))   
b = list(dict.fromkeys(b))

c.extend(a)

for i in b:
    if i not in c:
        c.append(i)

print('Union='+str(c))

f = []

for i in a:
    if i in b:
        f.append(i)

print('Intersection='+str(f))

# %% [markdown]
# Enter the range of first list:4
# Enter the range of second list:3
# Start entering the values into first list
#
# 2
# 2
# 3
# 4
# Start entering the values into second list
#
# 2
# 4
# 5
# Union=[2, 3, 4, 5]
# Intersection=[2, 4]

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 2
#
# Frequency Count Of Words

# %%
s1 = input('Enter the string:')

s1 = s1.split()

s2 = []

for i in s1:
    if i not in s2:
        s2.append(i)

for i in range(len(s2)):
    print(s1.count(s2[i]),' Occurance of ',s2[i])

# %% [markdown]
# Enter the string:hello i am i hello i am hello
# 3  Occurance of  hello
# 3  Occurance of  i
# 2  Occurance of  am

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 3
#
# Matrix Multiplication

# %%
p = int(input('Enter the no of rows of first matrix:'))
q = int(input('Enter the no of columns of first matrix:'))

m = int(input('Enter the no of rows of second matrix:'))
n = int(input('Enter the no of columns of second matrix:'))

def Multiply(p,q,m,n):
    a = []
    b = []
    c = []
    print('Start Entering the values of first matrix\n')
    for i in range(p):
        r = []
        for j in range(q):
            r.append(int(input()))
        a.append(r)
    
    print('Start entering the values of second matrix\n')
    for j in range(m):
        r = []
        for j in range(n):
            r.append(int(input()))
        b.append(r)
    
    print('Product Matrix\n')
    for i in range(p):
        r = []
        for j in range(n):
            d = 0
            for k in range(q):
                e = a[i][k]*b[k][j]
                d = d + e
            r.append(d)
        c.append(r)                

    for i in range(p):
        for j in range(n):
            print(c[i][j],end=' ')
        print()

if q == m:
    Multiply(p,q,m,n)
else:
    print('Sorry first matrix column and second matrix row does not match')

# %% [markdown]
# Enter the no of rows of first matrix:2
# Enter the no of columns of first matrix:3
# Enter the no of rows of second matrix:3
# Enter the no of columns of second matrix:2
# Start Entering the values of first matrix
#
# 1
# -2
# 1
# 2
# 1
# 3
# Start entering the values of second matrix
#
# 2
# 1
# 3
# 2
# 1
# 1
# Product Matrix
#
# -3 -2
# 10 7

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 4
#
# Longest Words

# %%
str = input('Enter the string:')
k = int(input('Enter the value for k:'))
str = str.lower()
string = []
text = str.split()
for i in text:
    if len(i)>k:
        if i not in string:
            string.append(i)
print(string)

# %% [markdown]
# Enter the string:Hello Moosa moosa i am jabbar
# Enter the value for k:2
# ['hello', 'moosa', 'jabbar']

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 5
#
# Find the most frequent words in text file

# %% [markdown]
# Sample text file data below
#
# Hi hi i am hi i am am

# %%
f = open('sample.txt','r')
g = f.read()
string = str(g)
string = string.lower().replace('.',' ').replace(',',' ').split()
a = []
a = list(dict.fromkeys(string))
word = []
words = a[0]
maxcount = len(a[0])
for i in range(len(a)):
    count = 0
    for j in range(len(string)):
        if a[i] == string[j]:
            count = count + 1
    if count >= maxcount:
        maxcount = count
        word.append(a[i])
print(word)

# %% [markdown]
# ['hi', 'am']

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 6
#
# Familirization with Matplotlib, Numpy, Pandas and Sklearn

# %% [markdown]
# No program just brief explanation about matplotlib

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 7
#
# Linear Regression
#  - Simple Linear Regression
#  - Polynomial Regression
#  - Linear Regression using backward elimination

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error,r2_score
import statsmodels.regression.linear_model as sm
import numpy as np

# %%
data1 = pd.read_csv('/home/lionex/bin/Python/Machine-Learning-Lab/Datasets/car_purchasing.csv', encoding='ISO-8859-1')
data1.shape
data1.head()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %%
sns.heatmap(data1.corr(),cmap='Blues', annot=True)
# Out:
# <Axes: >

# %%
X = data1[['age','annual Salary', 'net worth']]
y = data1['car purchase amount']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=21)
model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_pred,y_test)
r2 = r2_score(y_pred,y_test)
print('Mean Squared Error='+str(mse))
print('Efficiency of Model='+str(r2))
# Out:
# Mean Squared Error=2.314243958907386
# Efficiency of Model=0.9999999791592223

# %%
data = pd.read_csv('/home/lionex/bin/Python/Machine-Learning-Lab/Datasets/Position_Salaries.csv', encoding='ISO-8859-1')
data.shape
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  10 non-null     object
#  1   Level     10 non-null     int64
#  2   Salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
sns.heatmap(data.corr(),cmap='Blues', annot=True)
# Out:
# <Axes: >

# %%
X = data.iloc[:,1:2].values
y = data.iloc[:,2].values
poly = PolynomialFeatures(degree = 4)
p = poly.fit_transform(X)
poly.fit(p, y)
model = LinearRegression()
model.fit(p,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'blue')
plt.plot(X, model.predict(p), color = 'red')
plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
data2 = pd.read_csv('/home/lionex/bin/Python/Machine-Learning-Lab/Datasets/50_Startups.csv')
data2.head(5)
data2.shape
# Out:
# (50, 5)

# %%
sns.heatmap(data2.corr(),cmap='Blues',annot=True)
# Out:
# <Axes: >

# %%
x1 = pd.get_dummies(data2[['R&D Spend', 'Administration', 'Marketing Spend', 'State']])
x1.head(5)
y1 = data2['Profit']
X_train, X_test, y_train, y_test = train_test_split(x1,y1,test_size=0.3,random_state=4)
model1 = LinearRegression()
model1.fit(X_train,y_train)
y_pred = model1.predict(X_test)
mse1 = mean_squared_error(y_pred,y_test)
r21 = r2_score(y_pred,y_test)
print('Mean Squared Error='+str(mse1))
print('Efficiency of Model='+str(r21))
# Out:
# Mean Squared Error=88456329.66344424
# Efficiency of Model=0.9106288638054402

# %%
x1 = np.append(arr = np.ones((50, 1)).astype(int),values = x1, axis = 1)
opt = x1[:, [0, 1, 2, 3, 4, 5]]
ols = sm.OLS(endog = y1, exog = opt).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Wed, 23 Aug 2023   Prob (F-statistic):           1.34e-27
# Time:                        00:08:05   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.008e+04   6952.587      7.204      0.000    3.61e+04    6.41e+04
# x1             0.8060      0.046     17.369      0.000       0.712       0.900
# x2            -0.0270      0.052     -0.517      0.608      -0.132       0.078
# x3             0.0270      0.017      1.574      0.123      -0.008       0.062
# x4            41.8870   3256.039      0.013      0.990   -6520.229    6604.003
# x5           240.6758   3338.857      0.072      0.943   -6488.349    6969.701
# ==============================================================================
# Omnibus:                       14.782   Durbin-Watson:                   1.283
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.266
# Skew:                          -0.948   Prob(JB):                     2.41e-05
# Kurtosis:                       5.572   Cond. No.                     1.47e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
opt = x1[:, [0, 1, 2, 3, 5]]
ols = sm.OLS(endog = y1, exog = opt).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Wed, 23 Aug 2023   Prob (F-statistic):           8.49e-29
# Time:                        00:08:09   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.011e+04   6647.870      7.537      0.000    3.67e+04    6.35e+04
# x1             0.8060      0.046     17.606      0.000       0.714       0.898
# x2            -0.0270      0.052     -0.523      0.604      -0.131       0.077
# x3             0.0270      0.017      1.592      0.118      -0.007       0.061
# x4           220.1585   2900.536      0.076      0.940   -5621.821    6062.138
# ==============================================================================
# Omnibus:                       14.758   Durbin-Watson:                   1.282
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.172
# Skew:                          -0.948   Prob(JB):                     2.53e-05
# Kurtosis:                       5.563   Cond. No.                     1.40e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
opt = x1[:, [0, 1, 2, 3]]
ols = sm.OLS(endog = y1, exog = opt).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Wed, 23 Aug 2023   Prob (F-statistic):           4.53e-30
# Time:                        00:08:12   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# x1             0.8057      0.045     17.846      0.000       0.715       0.897
# x2            -0.0268      0.051     -0.526      0.602      -0.130       0.076
# x3             0.0272      0.016      1.655      0.105      -0.006       0.060
# ==============================================================================
# Omnibus:                       14.838   Durbin-Watson:                   1.282
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.442
# Skew:                          -0.949   Prob(JB):                     2.21e-05
# Kurtosis:                       5.586   Cond. No.                     1.40e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_train, X_test, y_train, y_test = train_test_split(opt,y1,test_size=0.3,random_state=3)
model1 = LinearRegression()
model1.fit(X_train,y_train)
y_pred = model1.predict(X_test)
print('Test Data')
mse1 = mean_squared_error(y_pred,y_test)
r21 = r2_score(y_pred,y_test)
adjr2 = 1 - ((1 - r2) * (len(data2) - 1) / (len(data2) - len(x1) - 1))
print('Mean Squared Error='+str(mse1))
print('Efficiency of Model='+str(r21))
print('Adjusted R2='+str(adjr2))
# Out:
# Test Data
# Mean Squared Error=109372381.72175032
# Efficiency of Model=0.9318095070765943
# Adjusted R2=1.0000010211981052

# %%
y_pred = model1.predict(X_train)
mse1 = mean_squared_error(y_pred,y_train)
r21 = r2_score(y_pred,y_train)
print('Train Data')
adjr2 = 1 - ((1 - r2) * (len(data2) - 1) / (len(data2) - len(y1) - 1))
print('Mean Squared Error='+str(mse1))
print('Efficiency of Model='+str(r21))
print('Adjusted R2='+str(adjr2))
# Out:
# Train Data
# Mean Squared Error=76252540.75219429
# Efficiency of Model=0.9503836407215878
# Adjusted R2=1.0000010211981052

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 8
#
# Logestic Regression

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score, r2_score, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('/home/lionex/bin/Python/Machine-Learning-Lab/Datasets/Social_Network_Ads.csv')
data.shape
data.info()
data.tail(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB
#      Age  EstimatedSalary  Purchased
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1

# %%
sns.heatmap(data.corr(), cmap='Blues', annot=True)
# Out:
# <Axes: >

# %%
X = data[['Age','EstimatedSalary']]
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
y = data['Purchased']
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.95,random_state=21)
model = LogisticRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print('Test Data')
print('Accuracy of the model = '+str(r2_score(y_pred,y_test)))
print('Recall Value='+str(recall_score(y_pred,y_test)))
print('Precision of the model='+str(precision_score(y_pred,y_test)))
print('F measure='+str(f1_score(y_pred,y_test)))
# Out:
# Test Data
# Accuracy of the model = 0.7333333333333334
# Recall Value=1.0
# Precision of the model=0.8333333333333334
# F measure=0.9090909090909091

# %%
print('Test Data')
cm = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(cm).plot()
# Out:
# Test Data

# %%
y_pred = model.predict(X_train)
print('Train Data')
print('Accuracy of the model = '+str(r2_score(y_pred,y_train)))
print('Recall Value='+str(recall_score(y_pred,y_train)))
print('Precision of the model='+str(precision_score(y_pred,y_train)))
print('F measure='+str(f1_score(y_pred,y_train)))
# Out:
# Train Data
# Accuracy of the model = 0.22690730106644807
# Recall Value=0.8260869565217391
# Precision of the model=0.6934306569343066
# F measure=0.753968253968254

# %%
print('Train Data')
cm = confusion_matrix(y_train, y_pred)
ConfusionMatrixDisplay(cm).plot()
# Out:
# Train Data

# %%
Introduction to ML Lab

Experiment No 9

Naive Bayes

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import f1_score,precision_score,recall_score,confusion_matrix, r2_score, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
data = pd.read_csv('//home/lionex/bin/Python/Machine-Learning-Lab/Datasets/Social_Network_Ads.csv')
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
sns.heatmap(data.corr(), cmap='Blues', annot=True)
# Out:
# <Axes: >

# %%
X = data[['Age','EstimatedSalary']]
y = data['Purchased']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
model = GaussianNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print('Test Data')
print('Accuracy of the model = '+str(r2_score(y_pred,y_test)))
print('Recall Value='+str(recall_score(y_pred,y_test)))
print('Precision of the model='+str(precision_score(y_pred,y_test)))
print('F measure='+str(f1_score(y_pred,y_test)))
# Out:
# Test Data
# Accuracy of the model = 0.7204751921733055
# Recall Value=0.9259259259259259
# Precision of the model=0.8928571428571429
# F measure=0.9090909090909091

# %%
cm = confusion_matrix(y_test,y_pred)
ConfusionMatrixDisplay(cm).plot()

# %%
y_pred = model.predict(X_train)
print('Train Data')
print('Accuracy of the model = '+str(r2_score(y_pred,y_train)))
print('Recall Value='+str(recall_score(y_pred,y_train)))
print('Precision of the model='+str(precision_score(y_pred,y_train)))
print('F measure='+str(f1_score(y_pred,y_train)))
# Out:
# Train Data
# Accuracy of the model = 0.3745454545454545
# Recall Value=0.86
# Precision of the model=0.7478260869565218
# F measure=0.7999999999999999

# %%
cm = confusion_matrix(y_train,y_pred)
ConfusionMatrixDisplay(cm).plot()

# %%
Introduction to ML Lab

Experiment No 10

Decision Tree

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import f1_score,precision_score,recall_score,confusion_matrix, r2_score, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn import tree

# %%
data = pd.read_csv('/home/lionex/bin/Python/Machine-Learning-Lab/Datasets/Social_Network_Ads.csv')
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
sns.heatmap(data.corr(), cmap='Blues', annot=True)
# Out:
# <Axes: >

# %%
X = data[['Age','EstimatedSalary']]
y = data['Purchased']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=21)

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
model = DecisionTreeClassifier()
model = model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print('Test Data')
print('Accuracy of the model = '+str(r2_score(y_pred,y_test)))
print('Recall Value='+str(recall_score(y_pred,y_test)))
print('Precision of the model='+str(precision_score(y_pred,y_test)))
print('F measure='+str(f1_score(y_pred,y_test)))
# Out:
# Test Data
# Accuracy of the model = 0.6581196581196582
# Recall Value=0.8461538461538461
# Precision of the model=0.9166666666666666
# F measure=0.8799999999999999

# %%
cm = confusion_matrix(y_pred,y_test)
ConfusionMatrixDisplay(cm).plot()

# %%
y_pred = model.predict(X_train)
print('Train Data')
print('Accuracy of the model = '+str(r2_score(y_pred,y_train)))
print('Recall Value='+str(recall_score(y_pred,y_train)))
print('Precision of the model='+str(precision_score(y_pred,y_train)))
print('F measure='+str(f1_score(y_pred,y_train)))
# Out:
# Train Data
# Accuracy of the model = 0.9865749286793086
# Recall Value=1.0
# Precision of the model=0.9915966386554622
# F measure=0.9957805907172996

# %%
cm = confusion_matrix(y_train,y_pred)
ConfusionMatrixDisplay(cm).plot()

# %%
fig = plt.figure(figsize=(25,20))
tr = tree.plot_tree(model, filled=True)

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 11
#
# Support Vector Machine

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import seaborn as sns
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score, recall_score, precision_score
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('Datasets/Social_Network_Ads.csv')
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
sns.heatmap(data.corr(),cmap='Blues',annot=True)
# Out:
# <Axes: >

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
scalar = StandardScaler()
X = scalar.fit_transform(X)

# %%
X_train , X_test, y_train, y_test = train_test_split(X,y,train_size=0.8,random_state=21)
model = SVC(gamma='auto')
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print('Accuracy = ', accuracy_score(y_pred,y_test))
print('Mean Square Error = ', mean_squared_error(y_pred,y_test))
print('R2 Score = ', r2_score(y_pred,y_test))
print('Recall = ', recall_score(y_pred,y_test,average='weighted'))
print('Precision = ', precision_score(y_pred,y_test, average='weighted'))
# Out:
# Accuracy =  0.925
# Mean Square Error =  0.075
# R2 Score =  0.6428571428571428
# Recall =  0.925
# Precision =  0.925

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 12
#
# K-Nearest Neighbour

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv("Datasets/Social_Network_Ads.csv")

# %%
sns.heatmap(data=df.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
X=df.iloc[:,:-1]
y=df["Purchased"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)

# %%
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
knn5 = KNeighborsClassifier(n_neighbors = 5)
knn1 = KNeighborsClassifier(n_neighbors=1)
knn5.fit(X_train, y_train)
knn1.fit(X_train, y_train)
y_pred_5 = knn5.predict(X_test)
y_pred_1 = knn1.predict(X_test)

# %%
print("Accuracy with k=5", accuracy_score(y_test, y_pred_5)*100)
print("Accuracy with k=1", accuracy_score(y_test, y_pred_1)*100)
# Out:
# Accuracy with k=5 93.0
# Accuracy with k=1 87.0

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.scatter(X_test[:,0], X_test[:,1], c=y_pred_5, marker= '*', s=100,edgecolors='black')
plt.title("Predicted values with k=5", fontsize=20)
plt.subplot(1,2,2)
plt.scatter(X_test[:,0], X_test[:,1], c=y_pred_1, marker= '*', s=100,edgecolors='black')
plt.title("Predicted values with k=1", fontsize=20)
plt.show()

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 13
#
# K-Means

# %%
import matplotlib.pyplot as plt    
import pandas as pd
from sklearn.cluster import KMeans

# %%
dataset = pd.read_csv('Datasets/Mall_Customers.csv')  
x = dataset.iloc[:, [3, 4]].values

# %%
wcss_list= []   
for i in range(1, 11):  
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state= 42)  
    kmeans.fit(x)  
    wcss_list.append(kmeans.inertia_)
# Out:
# /home/lionex/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/lionex/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/lionex/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/lionex/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/lionex/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/lionex/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/lionex/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/lionex/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/lionex/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/lionex/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.plot(range(1, 11), wcss_list)  
plt.title('The Elobw Method Graph')  
plt.xlabel('Number of clusters(k)')  
plt.ylabel('wcss_list')  
plt.show()

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state= 42)  
y_predict= kmeans.fit_predict(x)
# Out:
# /home/lionex/.local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.scatter(x[y_predict == 0, 0], x[y_predict == 0, 1], s = 100, c = 'blue', label = 'Cluster 1') 
plt.scatter(x[y_predict == 1, 0], x[y_predict == 1, 1], s = 100, c = 'green', label = 'Cluster 2') 
plt.scatter(x[y_predict== 2, 0], x[y_predict == 2, 1], s = 100, c = 'red', label = 'Cluster 3') 
plt.scatter(x[y_predict == 3, 0], x[y_predict == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4') 
plt.scatter(x[y_predict == 4, 0], x[y_predict == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5') 
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroid')   
plt.title('Clusters of customers')  
plt.xlabel('Annual Income (k$)')  
plt.ylabel('Spending Score (1-100)')  
plt.legend()  
plt.show()

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 14
#
# ANN Using Back Propagation

# %%
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential 
from keras.layers import Dense 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
# Out:
# 2023-08-23 10:11:29.016053: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-23 10:11:29.045734: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-23 10:11:29.046323: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-23 10:11:29.980683: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dataset= pd.read_csv('Datasets/Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
sns.heatmap(data=dataset.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
X= dataset.iloc[:,3:-1]
y=dataset.iloc[:,-1]

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender= pd.get_dummies(X['Gender'],drop_first=True)
X=pd.concat([X,geography,gender],axis=1)
X.drop(['Geography','Gender'],axis=1,inplace=True)

# %%
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0               1        101348.88        0      0     0
# 1               1        112542.58        0      1     0
# 2               0        113931.57        0      0     0
# 3               0         93826.63        0      0     0
# 4               1         79084.10        0      1     0

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
classifier= Sequential()
classifier.add(Dense(units=6,kernel_initializer='he_uniform',activation='relu',input_dim=11))
classifier.add(Dense(units=6,kernel_initializer='he_uniform',activation='relu'))
classifier.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 72
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dense_2 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_history=classifier.fit(X_train,y_train,validation_split=0.33,batch_size=10,epochs=50)
# Out:
# Epoch 1/50
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7472 - val_loss: 0.4764 - val_accuracy: 0.7959
# Epoch 2/50
# 536/536 [==============================] - 0s 867us/step - loss: 0.4641 - accuracy: 0.7960 - val_loss: 0.4560 - val_accuracy: 0.7997
# Epoch 3/50
# 536/536 [==============================] - 0s 816us/step - loss: 0.4450 - accuracy: 0.8000 - val_loss: 0.4422 - val_accuracy: 0.8065
# Epoch 4/50
# 536/536 [==============================] - 0s 859us/step - loss: 0.4320 - accuracy: 0.8033 - val_loss: 0.4344 - val_accuracy: 0.8088
# Epoch 5/50
# 536/536 [==============================] - 0s 795us/step - loss: 0.4228 - accuracy: 0.8119 - val_loss: 0.4275 - val_accuracy: 0.8092
# Epoch 6/50
# 536/536 [==============================] - 0s 879us/step - loss: 0.4140 - accuracy: 0.8164 - val_loss: 0.4214 - val_accuracy: 0.8122
# Epoch 7/50
# 536/536 [==============================] - 0s 818us/step - loss: 0.4052 - accuracy: 0.8186 - val_loss: 0.4127 - val_accuracy: 0.8145
# Epoch 8/50
# 536/536 [==============================] - 0s 854us/step - loss: 0.3950 - accuracy: 0.8235 - val_loss: 0.4038 - val_accuracy: 0.8232
# Epoch 9/50
# 536/536 [==============================] - 0s 834us/step - loss: 0.3844 - accuracy: 0.8321 - val_loss: 0.3969 - val_accuracy: 0.8281
# Epoch 10/50
# 536/536 [==============================] - 0s 814us/step - loss: 0.3757 - accuracy: 0.8397 - val_loss: 0.3919 - val_accuracy: 0.8315
# Epoch 11/50
# 536/536 [==============================] - 0s 811us/step - loss: 0.3691 - accuracy: 0.8390 - val_loss: 0.3875 - val_accuracy: 0.8357
# Epoch 12/50
# 536/536 [==============================] - 0s 831us/step - loss: 0.3646 - accuracy: 0.8423 - val_loss: 0.3852 - val_accuracy: 0.8368
# Epoch 13/50
# 536/536 [==============================] - 0s 816us/step - loss: 0.3609 - accuracy: 0.8455 - val_loss: 0.3822 - val_accuracy: 0.8395
# Epoch 14/50
# 536/536 [==============================] - 0s 835us/step - loss: 0.3581 - accuracy: 0.8470 - val_loss: 0.3794 - val_accuracy: 0.8417
# Epoch 15/50
# 536/536 [==============================] - 0s 845us/step - loss: 0.3544 - accuracy: 0.8494 - val_loss: 0.3788 - val_accuracy: 0.8444
# Epoch 16/50
# 536/536 [==============================] - 0s 832us/step - loss: 0.3528 - accuracy: 0.8492 - val_loss: 0.3755 - val_accuracy: 0.8455
# Epoch 17/50
# 536/536 [==============================] - 0s 821us/step - loss: 0.3502 - accuracy: 0.8513 - val_loss: 0.3743 - val_accuracy: 0.8448
# Epoch 18/50
# 536/536 [==============================] - 0s 818us/step - loss: 0.3491 - accuracy: 0.8517 - val_loss: 0.3727 - val_accuracy: 0.8470
# Epoch 19/50
# 536/536 [==============================] - 0s 824us/step - loss: 0.3473 - accuracy: 0.8533 - val_loss: 0.3707 - val_accuracy: 0.8508
# Epoch 20/50
# 536/536 [==============================] - 0s 822us/step - loss: 0.3460 - accuracy: 0.8533 - val_loss: 0.3695 - val_accuracy: 0.8485
# Epoch 21/50
# 536/536 [==============================] - 0s 829us/step - loss: 0.3448 - accuracy: 0.8554 - val_loss: 0.3691 - val_accuracy: 0.8512
# Epoch 22/50
# 536/536 [==============================] - 0s 795us/step - loss: 0.3430 - accuracy: 0.8556 - val_loss: 0.3677 - val_accuracy: 0.8516
# Epoch 23/50
# 536/536 [==============================] - 0s 818us/step - loss: 0.3421 - accuracy: 0.8572 - val_loss: 0.3684 - val_accuracy: 0.8489
# Epoch 24/50
# 536/536 [==============================] - 0s 804us/step - loss: 0.3413 - accuracy: 0.8580 - val_loss: 0.3658 - val_accuracy: 0.8512
# Epoch 25/50
# 536/536 [==============================] - 0s 799us/step - loss: 0.3399 - accuracy: 0.8558 - val_loss: 0.3659 - val_accuracy: 0.8523
# Epoch 26/50
# 536/536 [==============================] - 0s 806us/step - loss: 0.3397 - accuracy: 0.8569 - val_loss: 0.3653 - val_accuracy: 0.8501
# Epoch 27/50
# 536/536 [==============================] - 0s 823us/step - loss: 0.3385 - accuracy: 0.8574 - val_loss: 0.3649 - val_accuracy: 0.8504
# Epoch 28/50
# 536/536 [==============================] - 0s 816us/step - loss: 0.3369 - accuracy: 0.8578 - val_loss: 0.3659 - val_accuracy: 0.8493
# Epoch 29/50
# 536/536 [==============================] - 0s 815us/step - loss: 0.3364 - accuracy: 0.8584 - val_loss: 0.3638 - val_accuracy: 0.8497
# Epoch 30/50
# 536/536 [==============================] - 0s 820us/step - loss: 0.3359 - accuracy: 0.8558 - val_loss: 0.3626 - val_accuracy: 0.8504
# Epoch 31/50
# 536/536 [==============================] - 0s 792us/step - loss: 0.3351 - accuracy: 0.8580 - val_loss: 0.3626 - val_accuracy: 0.8504
# Epoch 32/50
# 536/536 [==============================] - 0s 796us/step - loss: 0.3346 - accuracy: 0.8591 - val_loss: 0.3613 - val_accuracy: 0.8554
# Epoch 33/50
# 536/536 [==============================] - 0s 817us/step - loss: 0.3334 - accuracy: 0.8597 - val_loss: 0.3614 - val_accuracy: 0.8527
# Epoch 34/50
# 536/536 [==============================] - 0s 788us/step - loss: 0.3329 - accuracy: 0.8608 - val_loss: 0.3604 - val_accuracy: 0.8535
# Epoch 35/50
# 536/536 [==============================] - 0s 813us/step - loss: 0.3316 - accuracy: 0.8628 - val_loss: 0.3601 - val_accuracy: 0.8542
# Epoch 36/50
# 536/536 [==============================] - 0s 832us/step - loss: 0.3315 - accuracy: 0.8615 - val_loss: 0.3609 - val_accuracy: 0.8561
# Epoch 37/50
# 536/536 [==============================] - 0s 824us/step - loss: 0.3309 - accuracy: 0.8615 - val_loss: 0.3601 - val_accuracy: 0.8554
# Epoch 38/50
# 536/536 [==============================] - 0s 817us/step - loss: 0.3304 - accuracy: 0.8632 - val_loss: 0.3589 - val_accuracy: 0.8554
# Epoch 39/50
# 536/536 [==============================] - 0s 802us/step - loss: 0.3299 - accuracy: 0.8651 - val_loss: 0.3597 - val_accuracy: 0.8531
# Epoch 40/50
# 536/536 [==============================] - 0s 802us/step - loss: 0.3299 - accuracy: 0.8612 - val_loss: 0.3590 - val_accuracy: 0.8535
# Epoch 41/50
# 536/536 [==============================] - 0s 812us/step - loss: 0.3286 - accuracy: 0.8647 - val_loss: 0.3590 - val_accuracy: 0.8576
# Epoch 42/50
# 536/536 [==============================] - 0s 821us/step - loss: 0.3292 - accuracy: 0.8628 - val_loss: 0.3597 - val_accuracy: 0.8557
# Epoch 43/50
# 536/536 [==============================] - 0s 832us/step - loss: 0.3289 - accuracy: 0.8656 - val_loss: 0.3592 - val_accuracy: 0.8527
# Epoch 44/50
# 536/536 [==============================] - 0s 845us/step - loss: 0.3291 - accuracy: 0.8638 - val_loss: 0.3601 - val_accuracy: 0.8531
# Epoch 45/50
# 536/536 [==============================] - 0s 823us/step - loss: 0.3282 - accuracy: 0.8632 - val_loss: 0.3586 - val_accuracy: 0.8565
# Epoch 46/50
# 536/536 [==============================] - 0s 838us/step - loss: 0.3280 - accuracy: 0.8634 - val_loss: 0.3611 - val_accuracy: 0.8519
# Epoch 47/50
# 536/536 [==============================] - 0s 847us/step - loss: 0.3279 - accuracy: 0.8656 - val_loss: 0.3593 - val_accuracy: 0.8542
# Epoch 48/50
# 536/536 [==============================] - 0s 838us/step - loss: 0.3281 - accuracy: 0.8640 - val_loss: 0.3589 - val_accuracy: 0.8550
# Epoch 49/50
# 536/536 [==============================] - 0s 866us/step - loss: 0.3270 - accuracy: 0.8662 - val_loss: 0.3599 - val_accuracy: 0.8554
# Epoch 50/50
# 536/536 [==============================] - 0s 830us/step - loss: 0.3272 - accuracy: 0.8651 - val_loss: 0.3607 - val_accuracy: 0.8531

# %%
y_pred= classifier.predict(X_test)
y_pred= (y_pred>0.5)
# Out:
# 63/63 [==============================] - 0s 484us/step

# %%
cm= confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[1519   76]
#  [ 195  210]]

# %%
accuracy=accuracy_score(y_test,y_pred)
print('The accuracy of the model is',accuracy)
cl_report = classification_report(y_test,y_pred)
print(cl_report)
print(model_history.history.keys())
# Out:
# The accuracy of the model is 0.8645
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      1595
#            1       0.73      0.52      0.61       405
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.74      0.76      2000
# weighted avg       0.86      0.86      0.86      2000
#
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Introduction to ML Lab
#
# Experiment No 15
#
# Principal Component Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib.colors import ListedColormap

# %%
dataset = pd.read_csv('Datasets/Wine.csv')

# %%
sns.heatmap(data=dataset.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
X = dataset.iloc[:, 0:13].values
y = dataset.iloc[:, 13].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
pca = PCA(n_components = 2)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
classifier = LogisticRegression(random_state = 21)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)          
print(cm)
# Out:
# [[14  0  0]
#  [ 1 15  0]
#  [ 0  0  6]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9722222222222222

# %%
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01), np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))

# %%
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),alpha = 0.75, cmap = ListedColormap(('red', 'green', 'blue')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],c = ListedColormap(('white', 'brown', 'darkblue'))(i), label = j)
# Out:
# /tmp/ipykernel_8396/611606359.py:5: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],c = ListedColormap(('white', 'brown', 'darkblue'))(i), label = j)
